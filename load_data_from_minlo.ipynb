# %%
pip install pandas minio pyarrow
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------------------- ---------------- 1.0/1.8 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 2.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from minio import Minio
import io

client = Minio("localhost:9000", access_key="minioadmin", secret_key="minioadminpassword", secure=False)

weather = pd.read_csv(io.BytesIO(client.get_object("bronze", "weather_raw.csv").read()))
traffic = pd.read_csv(io.BytesIO(client.get_object("bronze", "traffic_raw.csv").read()))

print("NO. or weather record:", len(weather), "records")
print("NO. or traffic record:", len(traffic), "record")
# Out:
# NO. or weather record: 5200 records
# NO. or traffic record: 5200 record

# %%
print (weather.head())
# Out:
#    weather_id            date_time    city  season  temperature_c  humidity  \
# 0        7799  2024-01-12 01:00:31  London     NaN      17.594582        80
# 1        5274  2024-03-07 21:02:11  London  Summer      38.138247        68
# 2        5432  2024-04-16 23:20:53  London  Winter      24.902900        66
# 3        5271  2024-01-15 20:04:56     NaN     NaN       9.037985        53
# 4        7582  2024-01-25 11:29:32  London  Autumn      23.239735        58
#
#      rain_mm  wind_speed_kmh  visibility_m weather_condition  air_pressure_hpa
# 0  17.145126              45          4430              Rain       1010.178686
# 1   6.491261              43          1697               Fog        988.200573
# 2   0.580755               6          9552             Storm        995.836457
# 3   3.098595              51          6603               Fog        984.544353
# 4   3.032774              23          2709             Clear        993.176079

# %%
print (traffic.head())
# Out:
#    traffic_id            date_time    city       area  vehicle_count  \
# 0       14619  2024-03-02 20:54:33  London     Camden           3277
# 1       16638  2024-03-05 22:25:59  London  Southwark           2592
# 2       14606  2024-09-22 16:16:03     NaN     Camden            536
# 3       11489  2024-11-17 07:42:10  London    Chelsea           2194
# 4       17023  2024-08-07 12:27:00  London  Southwark           4343
#
#    avg_speed_kmh  accident_count congestion_level road_condition  visibility_m
# 0             99               4           Medium          Snowy          9077
# 1             80               4              Low            Dry          7146
# 2             73               3              Low            Wet           959
# 3             41               3              NaN            NaN          6663
# 4             80               1             High            NaN          7872
